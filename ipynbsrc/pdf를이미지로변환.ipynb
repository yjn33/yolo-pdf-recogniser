# %%
from pdf2image import convert_from_path

# 변환할 pdf
images = convert_from_path("/home/zen35/Desktop/testdata/3.pdf", dpi=300)


#images = convert_from_path("/home/zen35/Desktop/makedata/1.pdf", dpi=300)

# pdf전체를 이미지로 저장
for i, image in enumerate(images):
    image.save(f"/home/zen35/Desktop/testdata/3_{i}.png", "PNG")
